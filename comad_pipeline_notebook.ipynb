# %% [markdown]
# # NeuFit Modeling Pipeline

# %% [markdown]
# ### Assumptions
# - This Jupyter notebook runs best in Kernel: **neufit**

# %% [markdown]
# ### Import Functions

# %%
from comad.neufit import neufit, comad_pipeline
from comad.utils import biom2data_tax

import matplotlib
# %matplotlib inline

# %% [markdown]
# ## Choose Dataseet + Run Pipeline

# %% [markdown]
# ### Hutch Kraken Dataset: Ludmil Alexandrov

# %% [markdown]
# #### Host Depleted: CHM13 + HG38; WOL / Woltka

# %% [markdown]
# ##### NP (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/NP/NP_be_wol_species.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_WOL_chm13Hg38_species_NP' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_WOL_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True)
# Out:
# Running dataset:HutchWoltka_WOL_chm13Hg38_species_NP
#
# dropping sample PCGA.1078.BE.02 with 5716 reads < 30000
# dropping sample PCGA.1119.BE.02 with 6350 reads < 30000
# dropping sample PCGA.1131.BE.01 with 10072 reads < 30000
# dropping sample PCGA.1132.BE.02 with 1877 reads < 30000
# dropping sample PCGA.1078.BE.04 with 24616 reads < 30000
# dropping sample PCGA.1130.BE.04 with 28818 reads < 30000
# dropping sample PCGA.1132.BE.01 with 28342 reads < 30000
# dropping sample PCGA.1131.BE.02 with 23008 reads < 30000
# dropping sample PCGA.1113.BE.03 with 29142 reads < 30000
# dropping sample PCGA.1132.BE.03 with 22541 reads < 30000
# dropping sample PCGA.1078.BE.03 with 24384 reads < 30000
# dropping sample PCGA.1078.BE.01 with 3428 reads < 30000
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 14
#     # data points      = 896
#     # variables        = 1
#     chi-square         = 4.69147694
#     reduced chi-square = 0.00524187
# ...

# %% [markdown]
# ##### Prog (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/Prog/Prog_be_wol_species.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_WOL_chm13Hg38_species_Prog' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_WOL_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True)
# Out:
# Running dataset:HutchWoltka_WOL_chm13Hg38_species_Prog
#
# dropping sample PCGA.1091.BE.03 with 9848 reads < 30000
# dropping sample PCGA.1080.BE.04 with 27275 reads < 30000
# dropping sample PCGA.1102.BE.03 with 22196 reads < 30000
# dropping sample PCGA.1091.BE.01 with 2461 reads < 30000
# dropping sample PCGA.1102.BE.01 with 14323 reads < 30000
# dropping sample PCGA.1094.BE.04 with 22358 reads < 30000
# dropping sample PCGA.1079.BE.02 with 29940 reads < 30000
# dropping sample PCGA.1129.BE.03 with 23500 reads < 30000
# dropping sample PCGA.1074.BE.02 with 5272 reads < 30000
# dropping sample PCGA.1129.BE.01 with 22775 reads < 30000
# dropping sample PCGA.1129.BE.02 with 1386 reads < 30000
# dropping sample PCGA.1080.BE.03 with 29633 reads < 30000
# dropping sample PCGA.1091.BE.04 with 28763 reads < 30000
# dropping sample PCGA.1074.BE.03 with 2537 reads < 30000
# dropping sample PCGA.1088.BE.04 with 29776 reads < 30000
# dropping sample PCGA.1094.BE.03 with 24022 reads < 30000
# ...

# %% [markdown]
# #### Host Depleted: CHM13 + HG38; REP 200 / Woltka

# %% [markdown]
# ##### NP (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/NP/NP_be_rep200_species.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_Rep200_chm13Hg38_species_NP' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_Rep200_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True)
# Out:
# Running dataset:HutchWoltka_Rep200_chm13Hg38_species_NP
#
# dropping sample PCGA.1131.BE.02 with 23080 reads < 30000
# dropping sample PCGA.1078.BE.04 with 24637 reads < 30000
# dropping sample PCGA.1113.BE.03 with 29287 reads < 30000
# dropping sample PCGA.1078.BE.01 with 3437 reads < 30000
# dropping sample PCGA.1131.BE.01 with 10286 reads < 30000
# dropping sample PCGA.1078.BE.02 with 5739 reads < 30000
# dropping sample PCGA.1078.BE.03 with 24437 reads < 30000
# dropping sample PCGA.1132.BE.02 with 1896 reads < 30000
# dropping sample PCGA.1130.BE.04 with 28890 reads < 30000
# dropping sample PCGA.1132.BE.03 with 22612 reads < 30000
# dropping sample PCGA.1132.BE.01 with 29172 reads < 30000
# dropping sample PCGA.1119.BE.02 with 6357 reads < 30000
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 1513
#     # variables        = 1
#     chi-square         = 9.71795025
#     reduced chi-square = 0.00642722
# ...

# %% [markdown]
# ##### P (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/Prog/Prog_be_rep200_species.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_Rep200_chm13Hg38_species_Prog' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_Rep200_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True)
# Out:
# Running dataset:HutchWoltka_Rep200_chm13Hg38_species_Prog
#
# dropping sample PCGA.1091.BE.04 with 28831 reads < 30000
# dropping sample PCGA.1129.BE.01 with 22902 reads < 30000
# dropping sample PCGA.1074.BE.03 with 2535 reads < 30000
# dropping sample PCGA.1102.BE.03 with 22922 reads < 30000
# dropping sample PCGA.1094.BE.04 with 22396 reads < 30000
# dropping sample PCGA.1088.BE.04 with 29911 reads < 30000
# dropping sample PCGA.1091.BE.01 with 2504 reads < 30000
# dropping sample PCGA.1102.BE.01 with 14332 reads < 30000
# dropping sample PCGA.1094.BE.03 with 24037 reads < 30000
# dropping sample PCGA.1129.BE.03 with 23674 reads < 30000
# dropping sample PCGA.1080.BE.04 with 27270 reads < 30000
# dropping sample PCGA.1129.BE.02 with 1399 reads < 30000
# dropping sample PCGA.1129.BE.04 with 19809 reads < 30000
# dropping sample PCGA.1079.BE.02 with 29941 reads < 30000
# dropping sample PCGA.1074.BE.02 with 5270 reads < 30000
# ...

# %% [markdown]
# ##### Combined Data (everything in the dataset)

# %%
#Path of biom file
biom_filename = '/Users/cguccion/Dropbox/Storage/RawData/01_11_2021_Hutch340_BE_Samples_LudmilAlexandrov/woltka_tissue/Rep200/Rep200_species.biom' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_Rep200_chm13Hg38_species_combined' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_Rep200_Results' 

comad_pipeline(biom_filename, output_filename, output_filepath, 30000, True)
# Out:
# Running dataset:HutchWoltka_Rep200_chm13Hg38_species_combined
#
# dropping sample PCGA-1091-BE-04 with 28831 reads < 30000
# dropping sample PCGA-1131-BE-02 with 23080 reads < 30000
# dropping sample PCGA-1129-BE-01 with 22902 reads < 30000
# dropping sample PCGA-1074-BE-03 with 2535 reads < 30000
# dropping sample PCGA-1102-BE-03 with 22922 reads < 30000
# dropping sample PCGA-1094-BE-04 with 22396 reads < 30000
# dropping sample PCGA-1088-BE-04 with 29911 reads < 30000
# dropping sample PCGA-1131-BE-05 with 13530 reads < 30000
# dropping sample PCGA-1091-BE-01 with 2504 reads < 30000
# dropping sample PCGA-1078-BE-04 with 24637 reads < 30000
# dropping sample PCGA-1113-BE-03 with 29287 reads < 30000
# dropping sample PCGA-1102-BE-01 with 14332 reads < 30000
# dropping sample PCGA-1094-BE-03 with 24037 reads < 30000
# dropping sample PCGA-1129-BE-03 with 23674 reads < 30000
# dropping sample PCGA-1078-BE-01 with 3437 reads < 30000
# ...

# %% [markdown]
# #### Host Depleted: CHM13 + HG38; REP 200 / Woltka : WIS Filter

# %% [markdown]
# ##### NP (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/NP/NP_rep200_genome_wis.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_Rep200_chm13Hg38_genome_WIS_NP' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_Rep200_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True, HP_Color = False)
# Out:
# Running dataset:HutchWoltka_Rep200_chm13Hg38_genome_WIS_NP
#
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 28
#     # data points      = 68
#     # variables        = 1
#     chi-square         = 0.14594732
#     reduced chi-square = 0.00217832
#     Akaike info crit   = -415.793171
#     Bayesian info crit = -413.573663
# [[Variables]]
#     N:  34 (fixed)
#     m:  0.40225948 +/- 0.08414806 (20.92%) (init = 0.5)
#
#  R^2 = 0.90
# ...
#
# Top NonNeutral Microbes
# Empty DataFrame
# Columns: [Difference off Neutral Model]
# Index: []
# ...

# %% [markdown]
# ##### P (T1 and T2)

# %%
#Path of input file
input_filename = '/Users/cguccion/Dropbox/current_Winter23/EAC_progression_microbiome_analysis/EAC_progression_micorbial_analysis/split_data/individual_split/Prog/Prog_rep200_genome_wis.tsv' 

#Name/nickname of dataset
output_filename = 'HutchWoltka_Rep200_chm13Hg38_genome_WIS_P' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter23/HutchWoltka_Rep200_Results' 

comad_pipeline(input_filename, output_filename, output_filepath, 30000, True, HP_Color = False)
# Out:
# Running dataset:HutchWoltka_Rep200_chm13Hg38_genome_WIS_P
#
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 70
#     # variables        = 1
#     chi-square         = 0.04445095
#     reduced chi-square = 6.4422e-04
#     Akaike info crit   = -513.330486
#     Bayesian info crit = -511.081990
# [[Variables]]
#     N:  14 (fixed)
#     m:  0.53706438 +/- 0.42717587 (79.54%) (init = 0.5)
#
#  R^2 = 0.96
# ...
#
# Top NonNeutral Microbes
# Empty DataFrame
# Columns: [Difference off Neutral Model]
# Index: []
# ...

# %% [markdown]
# ## Spring '22 Below

# %% [markdown]
# ### Hutch Kraken Dataset: Ludmil Alexandrov

# %% [markdown]
# #### Combined Data (Everything in the dataset)

# %%
#Path of biom file
biom_filename = '/Users/cguccion/Dropbox/Storage/RawData/01_11_2021_Hutch340_BE_Samples_LudmilAlexandrov/biom/combined_biome' 

#Name/nickname of dataset
output_filename = 'HutchKraken_combined' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Winter22/CommunityAssemblyPlugin/comad/sample_output' 

comad_pipeline(biom_filename, output_filename, output_filepath)
# Out:
# Running dataset:HutchKraken_combined
#
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 5631
#     # variables        = 1
#     chi-square         = 15.2219302
#     reduced chi-square = 0.00270372
#     Akaike info crit   = -33295.8214
#     Bayesian info crit = -33289.1853
# [[Variables]]
#     N:  2108 (fixed)
#     m:  0.32107991 +/- 0.00838540 (2.61%) (init = 0.5)
#
#  R^2 = 0.82
# ...
#
# Top NonNeutral Microbes
#    Difference off Neutral Model   taxonomy_0         taxonomy_1  \
# 2                      0.958774   k__Viruses   p__Peploviricota
# 1                      0.933507   k__Viruses   p__Peploviricota
# 3                      0.749990  k__Bacteria  p__Proteobacteria
# 4                      0.638227  k__Bacteria  p__Proteobacteria
# 0                      0.586486  k__Bacteria  p__Proteobacteria
#
#                  taxonomy_2            taxonomy_3            taxonomy_4  \
# ...

# %% [markdown]
# # Esoph Data

# %%
#Path of biom file
biom_filename = '/Users/cguccion/Dropbox/current_Spring22/shotgun_mixed_normal_esoph/qiita/143917_species.biom' 

#Name/nickname of dataset
output_filename = 'shotgun_esoph_mixed' 

#Path of all output files
output_filepath = '/Users/cguccion/Dropbox/current_Spring22/shotgun_mixed_normal_esoph/qiita/' 

comad_pipeline(biom_filename, output_filename, output_filepath)
# Out:
# Running dataset:shotgun_esoph_mixed
#
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 8
#     # data points      = 708
#     # variables        = 1
#     chi-square         = 5.34938310
#     reduced chi-square = 0.00756631
#     Akaike info crit   = -3456.90770
#     Bayesian info crit = -3452.34525
# [[Variables]]
#     N:  1477 (fixed)
#     m:  0.56310107 +/- 0.04096546 (7.27%) (init = 0.5)
#
#  R^2 = 0.89
# ...
#
# Top NonNeutral Microbes
#    Difference off Neutral Model   taxonomy_0        taxonomy_1  \
# 0                      0.876532  k__Bacteria     p__Firmicutes
# 2                      0.586655  k__Bacteria  p__Bacteroidetes
# 1                      0.540663  k__Bacteria     p__Firmicutes
#
#          taxonomy_2          taxonomy_3             taxonomy_4  \
# 0        c__Bacilli  o__Lactobacillales    f__Lactobacillaceae
# 2    c__Bacteroidia    o__Bacteroidales  f__Porphyromonadaceae
# ...
